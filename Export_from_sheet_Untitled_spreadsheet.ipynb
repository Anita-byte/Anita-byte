# %% [markdown]
# <a href="https://colab.research.google.com/github/Anita-byte/Anita-byte/blob/main/Export_from_sheet_Untitled_spreadsheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gspread
import pandas as pd
from google.auth import default
from google.colab import auth
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)
spreadsheet = gc.open_by_key('16P9ULlzEHjGP_LaXWE_QstmEhKLmay2DS1eruvs4M-4')
worksheet = spreadsheet.get_worksheet(0)
df = pd.DataFrame(worksheet.get())
# Code for making the first row as header. Remove if not needed.
df.columns = df.iloc[0]
df = df.drop(0)
df.head()
# Out:
# 0 MODELYEAR   MAKE       MODEL VEHICLECLASS ENGINESIZE CYLINDERS TRANSMISSION  \
# 1      2014  ACURA         ILX      COMPACT          2         4          AS5
# 2      2014  ACURA         ILX      COMPACT        2.4         4           M6
# 3      2014  ACURA  ILX HYBRID      COMPACT        1.5         4          AV7
# 4      2014  ACURA     MDX 4WD  SUV - SMALL        3.5         6          AS6
# 5      2014  ACURA     RDX AWD  SUV - SMALL        3.5         6          AS6
#
# 0 FUELTYPE FUELCONSUMPTION_CITY FUELCONSUMPTION_HWY FUELCONSUMPTION_COMB  \
# 1        Z                  9.9                 6.7                  8.5
# 2        Z                 11.2                 7.7                  9.6
# 3        Z                    6                 5.8                  5.9
# 4        Z                 12.7                 9.1                 11.1
# 5        Z                 12.1                 8.7                 10.6
#
# 0 FUELCONSUMPTION_COMB_MPG CO2EMISSIONS
# ...

# %%
import gspread
import pandas as pd
from google.auth import default
from google.colab import auth
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)
spreadsheet = gc.open_by_key('16P9ULlzEHjGP_LaXWE_QstmEhKLmay2DS1eruvs4M-4')
worksheet = spreadsheet.get_worksheet(0)
df = pd.DataFrame(worksheet.get())
# Code for making the first row as header. Remove if not needed.
df.columns = df.iloc[0]
df = df.drop(0)
df.head()
# Out:
# 0 MODELYEAR   MAKE       MODEL VEHICLECLASS ENGINESIZE CYLINDERS TRANSMISSION  \
# 1      2014  ACURA         ILX      COMPACT          2         4          AS5
# 2      2014  ACURA         ILX      COMPACT        2.4         4           M6
# 3      2014  ACURA  ILX HYBRID      COMPACT        1.5         4          AV7
# 4      2014  ACURA     MDX 4WD  SUV - SMALL        3.5         6          AS6
# 5      2014  ACURA     RDX AWD  SUV - SMALL        3.5         6          AS6
#
# 0 FUELTYPE FUELCONSUMPTION_CITY FUELCONSUMPTION_HWY FUELCONSUMPTION_COMB  \
# 1        Z                  9.9                 6.7                  8.5
# 2        Z                 11.2                 7.7                  9.6
# 3        Z                    6                 5.8                  5.9
# 4        Z                 12.7                 9.1                 11.1
# 5        Z                 12.1                 8.7                 10.6
#
# 0 FUELCONSUMPTION_COMB_MPG CO2EMISSIONS
# ...
